# %%
import cv2

# Load the image
img = cv2.imread('Image/a.jpg')
clone = img.copy()
cropping = False
refPt = []

# Mouse callback function
def click_and_crop(event, x, y, flags, param):
    global refPt, cropping, img

    if event == cv2.EVENT_LBUTTONDOWN:
        refPt = [(x, y)]
        cropping = True

    elif event == cv2.EVENT_LBUTTONUP:
        refPt.append((x, y))
        cropping = False

        # Draw a rectangle around the selected region
        cv2.rectangle(img, refPt[0], refPt[1], (0, 255, 0), 2)
        cv2.imshow("image", img)

# Create a window and bind the function
cv2.namedWindow("image")
cv2.setMouseCallback("image", click_and_crop)

while True:
    cv2.imshow("image", img)
    key = cv2.waitKey(1) & 0xFF

    # Press 'r' to reset the selection
    if key == ord("r"):
        img = clone.copy()

    # Press 'c' to confirm crop
    elif key == ord("c"):
        break

cv2.destroyAllWindows()

# Crop and display
if len(refPt) == 2:
    roi = clone[refPt[0][1]:refPt[1][1], refPt[0][0]:refPt[1][0]]
    cv2.imshow("Cropped", roi)
    cv2.imwrite("cropped_output.jpg", roi)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/apd/.local/lib/python3.10/site-packages/cv2/qt/plugins"
